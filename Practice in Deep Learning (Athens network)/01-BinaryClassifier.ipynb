# %% [markdown]
# <a href="https://colab.research.google.com/github/mttcrn/AI-things/blob/main/Deep%20Learning/01-BinaryClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing keras and the required libraies

# %%
# Numpy is Python standard library for tensor manipulation
import numpy as np
# Seeding numpy random number generator for results reproducibility
np.random.seed(0)

# Matplotlib will be used for all plotting tasks
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Importing the Keras 2.x main module relying on tensorflow 2.x backend
import tensorflow as tf
import keras
print("Using tensorflow version " + str(tf.__version__))
print("Using keras version " + str(keras.__version__))
# Out:
# Using tensorflow version 2.9.2
# Using keras version 2.9.0

# %% [markdown]
# # Generating a dataset of non linearly separable points in a bidimensional feature space

# %%
# Sklearn will be used to generate our synthetic dataset
from sklearn import datasets

# Generate a population of 1000 samples with some noise
X, y = datasets.make_moons(n_samples=1000, noise=0.01, shuffle=True)

colors = ['steelblue' if label == 1 else 'darkred' for label in y]
plt.scatter(X[:,0], X[:,1], color=colors)
y.shape, X.shape
# Out:
# ((1000,), (1000, 2))

# %% [markdown]
# #Defining the neural network architecture

# %%
from keras.models import Sequential
from keras.layers import Dense
# Define our model object
model = Sequential()

# Fully connected neural network with one or more layers with sigmoid
# activation functions.
model.add(Dense(4, input_dim=2, activation='sigmoid'))

model.add(Dense(2, input_dim=4, activation='sigmoid'))

model.add(Dense(1, input_dim=2, activation='sigmoid'))

# %% [markdown]
# Instantiating a SGD optimizer and compiling the model

# %%
# Optimizer modules provide a number of optimization algorithms for updating
# a netwok parameters accoridng to the computed error gradients

# Defining our SGD (stokastic gradient descent) optimizer
# Experiment with different learning rates and observe how the training evolves
sgd = optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

# %%
# Compiling a model in Keras amounts to associating the optimizer to a model with an appropriate loss function
model.compile(optimizer=sgd, loss='mse', metrics = ['accuracy'])

# Have look at the model topology
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 2)                 10
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Training the network

# %%
# This is where the actual training-testing happens
# Number of epochs we want to train
epochs = 100
# We restrict the training to n_train_samples images to cut time
n_train_samples = 1000
# This is where the actual training happens (no test dataset is considered in this case)
# batch_size is 32 by default
history = model.fit(X[:n_train_samples], y[:n_train_samples], verbose=1, epochs=epochs, shuffle=True)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1763 - accuracy: 0.7630
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1760 - accuracy: 0.7640
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1756 - accuracy: 0.7650
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 0.7670
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.7650
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.7670
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1743 - accuracy: 0.7660
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1739 - accuracy: 0.7650
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.7670
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.7680
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1730 - accuracy: 0.7700
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1726 - accuracy: 0.7670
# Epoch 13/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1723 - accuracy: 0.7690
# Epoch 14/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1720 - accuracy: 0.7680
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1717 - accuracy: 0.7690
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1714 - accuracy: 0.7690
# Epoch 17/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1711 - accuracy: 0.7710
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.7720
# Epoch 19/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1704 - accuracy: 0.7720
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1701 - accuracy: 0.7720
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1698 - accuracy: 0.7720
# Epoch 22/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.7720
# Epoch 23/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1692 - accuracy: 0.7720
# Epoch 24/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.7730
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.7730
# Epoch 26/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1683 - accuracy: 0.7740
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1680 - accuracy: 0.7740
# Epoch 28/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.7740
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1673 - accuracy: 0.7730
# Epoch 30/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.7730
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1667 - accuracy: 0.7740
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1664 - accuracy: 0.7740
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1661 - accuracy: 0.7750
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1658 - accuracy: 0.7760
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.7750
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.7780
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.7780
# Epoch 38/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.7770
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1644 - accuracy: 0.7780
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.7770
# Epoch 41/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.7800
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.7800
# Epoch 43/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.7780
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.7800
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.7820
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1623 - accuracy: 0.7820
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.7830
# Epoch 48/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.7830
# Epoch 49/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1614 - accuracy: 0.7830
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.7830
# Epoch 51/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.7830
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.7830
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1603 - accuracy: 0.7840
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1600 - accuracy: 0.7840
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.7840
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1594 - accuracy: 0.7840
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 0.7840
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.7850
# Epoch 59/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.7850
# Epoch 60/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.7850
# Epoch 61/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 0.7860
# Epoch 62/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1578 - accuracy: 0.7860
# Epoch 63/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1575 - accuracy: 0.7870
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1572 - accuracy: 0.7880
# Epoch 65/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1569 - accuracy: 0.7880
# Epoch 66/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1567 - accuracy: 0.7880
# Epoch 67/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.7880
# Epoch 68/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.7880
# Epoch 69/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1559 - accuracy: 0.7880
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1556 - accuracy: 0.7880
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1553 - accuracy: 0.7880
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.7880
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.7880
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.7880
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.7880
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.7910
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.7920
# Epoch 78/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.7910
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 0.7930
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.7930
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.7940
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.7960
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1521 - accuracy: 0.7940
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.7950
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.7960
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1514 - accuracy: 0.7960
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.7960
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.7960
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1506 - accuracy: 0.7960
# Epoch 90/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1503 - accuracy: 0.7960
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1501 - accuracy: 0.7970
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1498 - accuracy: 0.7960
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1496 - accuracy: 0.7980
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1493 - accuracy: 0.7980
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1491 - accuracy: 0.7980
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1488 - accuracy: 0.7980
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.7980
# Epoch 98/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1483 - accuracy: 0.7980
# Epoch 99/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1481 - accuracy: 0.7980
# Epoch 100/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1478 - accuracy: 0.7980

# %% [markdown]
# # Evaluating the trained network

# %%
# We now want to plot the train and validation loss functions and accuracy curves
print(history.history.keys())

# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])

# %% [markdown]
# # Visualizing the decision plane learned by the network

# %%
# This function plots the output of the output neuron as a function of the network inputs
def plot_decision_boundary(X, y, model, steps=1000, cmap='Paired'):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    cmap = plt.get_cmap(cmap)

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min() - 1, X[:,0].max() + 1
    ymin, ymax = X[:,1].min() - 1, X[:,1].max() + 1
    steps = 1000
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])

    # Plot decision boundary in region of interest
    z = labels.reshape(xx.shape)

    fig, ax = plt.subplots()
    ax.contourf(xx, yy, z, cmap=cmap, alpha=0.5)

    # Get predicted labels on training data and plot
    train_labels = model.predict(X)
    ax.scatter(X[:,0], X[:,1], c=y, cmap=cmap, lw=0)

    return fig, ax

# %%
plot_decision_boundary(X, y, model, cmap='RdBu')
# Out:
# 31250/31250 [==============================] - 41s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe3551c53d0>)
